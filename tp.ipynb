# %%
import requests
from bs4 import BeautifulSoup

# %%
# Defining the url of the site
# base_site = "https://en.wikipedia.org/wiki/Music"

base_site = "https://jvjplus.github.io/resume"

# Making a get request
response = requests.get(base_site)
response.status_code
# Out:
# 200

# %%
html=response.content
html[:1000]
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n    <title>Jay Prakash Mahto</title>\n    <link href="https://fonts.googleapis.com/css?family=Ubuntu:700&display=swap" rel="stylesheet">\n    <link rel="stylesheet" href="https://use.fontawesome.com/releases/v5.8.2/css/all.css" integrity="sha384-oS3vJWv+0UjzBfQzYUhtDYW+Pj2yciDJxpsK1OYPAYjqT085Qq/1cq5FLXAZQ7Ay" crossorigin="anonymous">\n\n    <meta name="viewport" content="width=device-width, initial-scale=1.0">\n\n    <link rel="icon" href="https://raw.githubusercontent.com/JVJplus/resume/master/images/favicon.jpg" type="image/jpg" sizes="16x16">\n\n    <style>\nbody{\n\tmargin:0px;\n\tfont-family: sans-serif;\n\tfont-size: 16px;\n}\n\n#body-header{\n\twidth: 100vw;\n\theight: 65vh;\n\n\t/*background-image: url(images/bluredLights.jpg);*/\n\tbackground-image: url(https://ninjasfiles.s3.amazonaws.com/asset_0000000000000020_1549743985_macbook_mouse.jpg);\n\tbackground-size: cover;\n\tbackground-position: center;\n\topacity: 0.8;\n\tbackground-attachment: fixed;\n\t/*background-size: 100% 100%;*'

# %%
soup=BeautifulSoup(html,"html.parser")

# %%
with open('resume.html', 'wb') as file:
    file.write(soup.prettify("utf-8"));

# %%
soup.find_all('div')
# Out:
# [<div id="dropdown-container">
#  <div id="dropdown-icon">
#  <i class="fas fa-bars" id="bars"></i>
#  </div>
#  <div id="dropdown-menu">
#  <ul>
#  <li>
#  <a href="#body-header">Home</a>
#  </li>
#  <li>
#  <a href="#about">About</a>
#  </li>
#  <li>
#  <a href="#skills">Skills</a>
#  </li>
#  <li>
#  <a href="#experience">Experience</a>
#  </li>
#  <li>
#  <a href="#education">Education</a>
#  </li>
#  <li>
#  <a href="#portfolio">Portfolio</a>
#  </li>
#  <li>
#  <a href="#contact">Contact</a>
#  </li>
#  </ul>
#  </div> <!-- List -->
#  </div>,
#  <div id="dropdown-icon">
#  <i class="fas fa-bars" id="bars"></i>
#  </div>,
#  <div id="dropdown-menu">
#  <ul>
#  <li>
#  <a href="#body-header">Home</a>
#  </li>
#  <li>
#  <a href="#about">About</a>
#  </li>
#  <li>
#  <a href="#skills">Skills</a>
#  </li>
#  <li>
#  <a href="#experience">Experience</a>
#  </li>
#  <li>
#  <a href="#education">Education</a>
#  </li>
#  <li>
#  <a href="#portfolio">Portfolio</a>
#  </li>
#  <li>
#  <a href="#contact">Contact</a>
#  </li>
#  </ul>
#  </div>,
#  <div>
#  <ul class="horizontal-list" id="horizontalList">
#  <li class="horizontal-list-item"> <a href="#body-header">Home</a></li>
#  <li class="horizontal-list-item"> <a href="#about">About</a></li>
#  <li class="horizontal-list-item"> <a href="#skills">Skills</a></li>
#  <li class="horizontal-list-item"> <a href="#experience">Experience</a></li>
#  <li class="horizontal-list-item"> <a href="#education">Education</a></li>
#  <li class="horizontal-list-item"> <a href="#portfolio">Portfolio</a></li>
#  <li class="horizontal-list-item"> <a href="#contact">Contact</a></li>
#  </ul>
#  </div>,
#  <div id="dp-div">
#  <!-- <img id="dp" src="images/dp.jpeg"> -->
#  <a href="https://raw.githubusercontent.com/JVJplus/Resume-Webpage/master/images/dp2.jpg" target="_blank">
#  <img id="dp" src="https://raw.githubusercontent.com/JVJplus/Resume-Webpage/master/images/dp2.jpg"/>
#  </a>
#  </div>,
#  <div id="about">
#  <p class="about-para">
#  <span> Hi, </span> I am 19 years amateur, Living in Jamshedpur.
#                  </p>
#  <p class="about-para">
#                      Since Childhood I am an <span>Computer Enthusiast</span>, Die-Heart <span>Programmer</span> And <span>Graphics Designer</span>. Also have immense Interest in Learning New Upcoming Technologies.
#                  </p>
#  <p class="about-para">
#                      Now totally obsessed with <span>Android &amp; Guitar</span>.
#                  </p>
#  <p class="about-para">
#                      As a side work, had tried hands on Guitar, Competitive Programming, Dance(will).
#                  </p>
#  <p class="about-para">
#                      Currently looking for projects and internship based on <span>Android &amp; Web Development</span> to test my knowledge and boost experience.
#                  </p>
#  </div>,
#  <div class="section-header">
#  <i class="fas fa-chalkboard-teacher">
#  <span>Skills</span>
#  </i>
#  </div>,
#  <div class="skills-display">
#  <div class="behind-box">
#  <div class="upper-box" id="cpp-skill">
#  <span class="skill-name">
#                              C++
#                          </span>
#  </div>
#  </div>
#  <div class="behind-box">
#  <div class="upper-box" id="dsa-skill">
#  <span class="skill-name">
#                              DS &amp; ALGO
#                          </span>
#  </div>
#  </div>
#  <div class="behind-box">
#  <div class="upper-box" id="html-skill">
#  <span class="skill-name">
#                              HTML &amp; CSS
#                          </span>
#  </div>
#  </div>
#  <div class="behind-box">
#  <div class="upper-box" id="css-skill">
#  <span class="skill-name">
#                              Typing 75wpm
#                          </span>
#  </div>
#  </div>
#  <div class="behind-box">
#  <div class="upper-box" id="js-skill">
#  <span class="skill-name">
#                              JavaScript
#                          </span>
#  </div>
#  </div>
#  <div class="behind-box">
#  <div class="upper-box" id="ps-skill">
#  <span class="skill-name">
#                              Photoshop
#                          </span>
#  </div>
#  </div>
#  <div class="behind-box">
#  <div class="upper-box" id="premiere-skill">
#  <span class="skill-name">
#                              Illustrator
#                          </span>
#  </div>
#  </div>
#  <div class="behind-box">
#  <div class="upper-box" id="ae-skill">
#  <span class="skill-name">
#                              Android
#                          </span>
#  </div>
#  </div>
#  </div>,
#  <div class="behind-box">
#  <div class="upper-box" id="cpp-skill">
#  <span class="skill-name">
#                              C++
#                          </span>
#  </div>
#  </div>,
#  <div class="upper-box" id="cpp-skill">
#  <span class="skill-name">
#                              C++
#                          </span>
#  </div>,
#  <div class="behind-box">
#  <div class="upper-box" id="dsa-skill">
#  <span class="skill-name">
#                              DS &amp; ALGO
#                          </span>
#  </div>
#  </div>,
#  <div class="upper-box" id="dsa-skill">
#  <span class="skill-name">
#                              DS &amp; ALGO
#                          </span>
#  </div>,
#  <div class="behind-box">
#  <div class="upper-box" id="html-skill">
#  <span class="skill-name">
#                              HTML &amp; CSS
#                          </span>
#  </div>
#  </div>,
#  <div class="upper-box" id="html-skill">
#  <span class="skill-name">
#                              HTML &amp; CSS
#                          </span>
#  </div>,
#  <div class="behind-box">
#  <div class="upper-box" id="css-skill">
#  <span class="skill-name">
#                              Typing 75wpm
#                          </span>
#  </div>
#  </div>,
#  <div class="upper-box" id="css-skill">
#  <span class="skill-name">
#                              Typing 75wpm
#                          </span>
#  </div>,
#  <div class="behind-box">
#  <div class="upper-box" id="js-skill">
#  <span class="skill-name">
#                              JavaScript
#                          </span>
#  </div>
#  </div>,
#  <div class="upper-box" id="js-skill">
#  <span class="skill-name">
#                              JavaScript
#                          </span>
#  </div>,
#  <div class="behind-box">
#  <div class="upper-box" id="ps-skill">
#  <span class="skill-name">
#                              Photoshop
#                          </span>
#  </div>
#  </div>,
#  <div class="upper-box" id="ps-skill">
#  <span class="skill-name">
#                              Photoshop
#                          </span>
#  </div>,
#  <div class="behind-box">
#  <div class="upper-box" id="premiere-skill">
#  <span class="skill-name">
#                              Illustrator
#                          </span>
#  </div>
#  </div>,
#  <div class="upper-box" id="premiere-skill">
#  <span class="skill-name">
#                              Illustrator
#                          </span>
#  </div>,
#  <div class="behind-box">
#  <div class="upper-box" id="ae-skill">
#  <span class="skill-name">
#                              Android
#                          </span>
#  </div>
#  </div>,
#  <div class="upper-box" id="ae-skill">
#  <span class="skill-name">
#                              Android
#                          </span>
#  </div>,
#  <div class="exp-container">
#  <div class="exp-timeline-box">
#  <div class="exp-header">
#  <div class="exp-logo" style="margin-top: 10px ">
#  <img src="https://ninjasfiles.s3.amazonaws.com/asset_0000000000000030_1550710829_ninjasicon.png"/>
#  </div>
#  <div class="exp-degination">
#  <h2>Teaching Assistant </h2>
#  </div>
#  </div> <!-- Header -->
#  <div class="exp-company2" style="margin-top: -2%">
#  <a href="https://www.codingninjas.in/" style="text-decoration: none" target="_blank">
#  <h3>Coding Ninjas</h3>
#  </a>
#  </div> <!-- Company -->
#  <div class="exp-time">
#  <h4> May 2019 - 2019</h4>
#  </div>
#  <div class="exp-details">
#  <p>Helped Students to clear their doubt on the Online Data Structures Course Provided by Coding Ninjas on their website.
#                          <br/>
#  <br/>
#                          Solved More Than 1000 doubts from students with average ratings of 4.6 out of 5.
#
#                      </p>
#  </div> <!-- exp-details -->
#  </div> <!-- Timeline-box -->
#  <div class="exp-timeline-box">
#  <div class="exp-header">
#  <div class="exp-logo">
#  <img class="exp-smaller-img" src="https://raw.githubusercontent.com/JVJplus/resume/master/images/JVJplus%20colours%20logo.png"/>
#  </div>
#  <div class="exp-degination" style="padding: 0">
#  <h2>CEO &amp; Founding Member</h2>
#  </div>
#  </div> <!-- Header -->
#  <div class="exp-company" style="margin-top: 2%">
#  <a href="https://www.JVJplus.com/" style="text-decoration: none;" target="_blank">
#  <h3>JVJplus</h3>
#  </a>
#  </div> <!-- Company -->
#  <div class="exp-time">
#  <h4>Month YYYY - Month YYYY</h4>
#  </div>
#  <div class="exp-details">
#  <p>
#                          Company Isn't yet started :P.
#                          <br/>
#  <br/>
#                          But When it will i have that position. Basically it will be related to something related to computer only.
#                      </p>
#  </div> <!-- exp-details -->
#  </div> <!-- Timeline-box -->
#  <div class="exp-timeline-box">
#  <div class="exp-header">
#  <div class="exp-logo">
#  <!-- <img src="https://i.ibb.co/HXbSWkX/jvj-logo-new.png"> -->
#  <!-- <img src="https://i.ibb.co/Z14vP7t/jvj-logo-final.png"> -->
#  <img class="exp-smaller-img" src="https://raw.githubusercontent.com/JVJplus/resume/master/images/JVJplus%20colours%20logo.png"/>
#  </div>
#  <div class="exp-degination">
#  <h2>Administrator</h2>
#  </div>
#  </div> <!-- Header -->
#  <div class="exp-company exp-company-margin">
#  <a href="#" style="text-decoration: none" target="_blank">
#  <h3>This Website</h3>
#  </a>
#  </div> <!-- Company -->
#  <div class="exp-time">
#  <h4>June 2019 - Till Date </h4>
#  </div>
#  <div class="exp-details">
#  <p>So I dont have any else experience to fill up this section.
#                          <br/>
#  <br/>
#                          It took me around a month to develop the 1st starting page of this site. Starting from HTML, CSS the whole page is made of it by date 09-06-2019.  Will add some other function/features later.
#                      </p>
#  </div> <!-- exp-details -->
#  </div> <!-- Timeline-box -->
#  <!-- Timeline Divider -->
#  <div class="exp-timeline-divider">
#  <div class="timeline-traveller">
#  <div>
#  <i class="fas fa-plane"></i>
#  </div>
#  </div>
#  </div> <!-- Timline-Divider -->
#  </div>,
#  <div class="exp-timeline-box">
#  <div class="exp-header">
#  <div class="exp-logo" style="margin-top: 10px ">
#  <img src="https://ninjasfiles.s3.amazonaws.com/asset_0000000000000030_1550710829_ninjasicon.png"/>
#  </div>
#  <div class="exp-degination">
#  <h2>Teaching Assistant </h2>
#  </div>
#  </div> <!-- Header -->
#  <div class="exp-company2" style="margin-top: -2%">
#  <a href="https://www.codingninjas.in/" style="text-decoration: none" target="_blank">
#  <h3>Coding Ninjas</h3>
#  </a>
#  </div> <!-- Company -->
#  <div class="exp-time">
#  <h4> May 2019 - 2019</h4>
#  </div>
#  <div class="exp-details">
#  <p>Helped Students to clear their doubt on the Online Data Structures Course Provided by Coding Ninjas on their website.
#                          <br/>
#  <br/>
#                          Solved More Than 1000 doubts from students with average ratings of 4.6 out of 5.
#
#                      </p>
#  </div> <!-- exp-details -->
#  </div>,
#  <div class="exp-header">
#  <div class="exp-logo" style="margin-top: 10px ">
#  <img src="https://ninjasfiles.s3.amazonaws.com/asset_0000000000000030_1550710829_ninjasicon.png"/>
#  </div>
#  <div class="exp-degination">
#  <h2>Teaching Assistant </h2>
#  </div>
#  </div>,
#  <div class="exp-logo" style="margin-top: 10px ">
#  <img src="https://ninjasfiles.s3.amazonaws.com/asset_0000000000000030_1550710829_ninjasicon.png"/>
#  </div>,
#  <div class="exp-degination">
#  <h2>Teaching Assistant </h2>
#  </div>,
#  <div class="exp-company2" style="margin-top: -2%">
#  <a href="https://www.codingninjas.in/" style="text-decoration: none" target="_blank">
#  <h3>Coding Ninjas</h3>
#  </a>
#  </div>,
#  <div class="exp-time">
#  <h4> May 2019 - 2019</h4>
#  </div>,
#  <div class="exp-details">
#  <p>Helped Students to clear their doubt on the Online Data Structures Course Provided by Coding Ninjas on their website.
#                          <br/>
#  <br/>
#                          Solved More Than 1000 doubts from students with average ratings of 4.6 out of 5.
#
#                      </p>
#  </div>,
#  <div class="exp-timeline-box">
#  <div class="exp-header">
#  <div class="exp-logo">
#  <img class="exp-smaller-img" src="https://raw.githubusercontent.com/JVJplus/resume/master/images/JVJplus%20colours%20logo.png"/>
#  </div>
#  <div class="exp-degination" style="padding: 0">
#  <h2>CEO &amp; Founding Member</h2>
#  </div>
#  </div> <!-- Header -->
#  <div class="exp-company" style="margin-top: 2%">
#  <a href="https://www.JVJplus.com/" style="text-decoration: none;" target="_blank">
#  <h3>JVJplus</h3>
#  </a>
#  </div> <!-- Company -->
#  <div class="exp-time">
#  <h4>Month YYYY - Month YYYY</h4>
#  </div>
#  <div class="exp-details">
#  <p>
#                          Company Isn't yet started :P.
#                          <br/>
#  <br/>
#                          But When it will i have that position. Basically it will be related to something related to computer only.
#                      </p>
#  </div> <!-- exp-details -->
#  </div>,
#  <div class="exp-header">
#  <div class="exp-logo">
#  <img class="exp-smaller-img" src="https://raw.githubusercontent.com/JVJplus/resume/master/images/JVJplus%20colours%20logo.png"/>
#  </div>
#  <div class="exp-degination" style="padding: 0">
#  <h2>CEO &amp; Founding Member</h2>
#  </div>
#  </div>,
#  <div class="exp-logo">
#  <img class="exp-smaller-img" src="https://raw.githubusercontent.com/JVJplus/resume/master/images/JVJplus%20colours%20logo.png"/>
#  </div>,
#  <div class="exp-degination" style="padding: 0">
#  <h2>CEO &amp; Founding Member</h2>
#  </div>,
#  <div class="exp-company" style="margin-top: 2%">
#  <a href="https://www.JVJplus.com/" style="text-decoration: none;" target="_blank">
#  <h3>JVJplus</h3>
#  </a>
#  </div>,
#  <div class="exp-time">
#  <h4>Month YYYY - Month YYYY</h4>
#  </div>,
#  <div class="exp-details">
#  <p>
#                          Company Isn't yet started :P.
#                          <br/>
#  <br/>
#                          But When it will i have that position. Basically it will be related to something related to computer only.
#                      </p>
#  </div>,
#  <div class="exp-timeline-box">
#  <div class="exp-header">
#  <div class="exp-logo">
#  <!-- <img src="https://i.ibb.co/HXbSWkX/jvj-logo-new.png"> -->
#  <!-- <img src="https://i.ibb.co/Z14vP7t/jvj-logo-final.png"> -->
#  <img class="exp-smaller-img" src="https://raw.githubusercontent.com/JVJplus/resume/master/images/JVJplus%20colours%20logo.png"/>
#  </div>
#  <div class="exp-degination">
#  <h2>Administrator</h2>
#  </div>
#  </div> <!-- Header -->
#  <div class="exp-company exp-company-margin">
#  <a href="#" style="text-decoration: none" target="_blank">
#  <h3>This Website</h3>
#  </a>
#  </div> <!-- Company -->
#  <div class="exp-time">
#  <h4>June 2019 - Till Date </h4>
#  </div>
#  <div class="exp-details">
#  <p>So I dont have any else experience to fill up this section.
#                          <br/>
#  <br/>
#                          It took me around a month to develop the 1st starting page of this site. Starting from HTML, CSS the whole page is made of it by date 09-06-2019.  Will add some other function/features later.
#                      </p>
#  </div> <!-- exp-details -->
#  </div>,
#  <div class="exp-header">
#  <div class="exp-logo">
#  <!-- <img src="https://i.ibb.co/HXbSWkX/jvj-logo-new.png"> -->
#  <!-- <img src="https://i.ibb.co/Z14vP7t/jvj-logo-final.png"> -->
#  <img class="exp-smaller-img" src="https://raw.githubusercontent.com/JVJplus/resume/master/images/JVJplus%20colours%20logo.png"/>
#  </div>
#  <div class="exp-degination">
#  <h2>Administrator</h2>
#  </div>
#  </div>,
#  <div class="exp-logo">
#  <!-- <img src="https://i.ibb.co/HXbSWkX/jvj-logo-new.png"> -->
#  <!-- <img src="https://i.ibb.co/Z14vP7t/jvj-logo-final.png"> -->
#  <img class="exp-smaller-img" src="https://raw.githubusercontent.com/JVJplus/resume/master/images/JVJplus%20colours%20logo.png"/>
#  </div>,
#  <div class="exp-degination">
#  <h2>Administrator</h2>
#  </div>,
#  <div class="exp-company exp-company-margin">
#  <a href="#" style="text-decoration: none" target="_blank">
#  <h3>This Website</h3>
#  </a>
#  </div>,
#  <div class="exp-time">
#  <h4>June 2019 - Till Date </h4>
#  </div>,
#  <div class="exp-details">
#  <p>So I dont have any else experience to fill up this section.
#                          <br/>
#  <br/>
#                          It took me around a month to develop the 1st starting page of this site. Starting from HTML, CSS the whole page is made of it by date 09-06-2019.  Will add some other function/features later.
#                      </p>
#  </div>,
#  <div class="exp-timeline-divider">
#  <div class="timeline-traveller">
#  <div>
#  <i class="fas fa-plane"></i>
#  </div>
#  </div>
#  </div>,
#  <div class="timeline-traveller">
#  <div>
#  <i class="fas fa-plane"></i>
#  </div>
#  </div>,
#  <div>
#  <i class="fas fa-plane"></i>
#  </div>,
#  <div class="exp-container">
#  <div class="exp-timeline-box">
#  <div class="exp-header">
#  <div class="exp-logo2" style="margin-top: 10px ">
#  <img src="https://github.com/JVJplus/resume/blob/master/images/dav-logo-removebg-preview.png?raw=true"/>
#  </div>
#  <div class="exp-degination2">
#  <h2>Board</h2>
#  </div>
#  </div> <!-- Header -->
#  <div class="exp-company" style="margin-top: -7%">
#  <a href="http://www.davpatelnagar.com/" style="text-decoration: none" target="_blank">
#  <h3>DAV Public School</h3>
#  </a>
#  </div> <!-- Intitution -->
#  <div class="exp-time2">
#  <h4> 2007 - May 2017 </h4>
#  </div>
#  <div class="exp-details2">
#  <p>
#                      Given my board exam from ICSE Board with Science Stream and secured 85.4%. I was also 2nd school topper. Also I got 99% marks in computer science.
#                  </p>
#  </div> <!-- edu-details -->
#  </div> <!-- Timeline-box -->
#  <div class="exp-timeline-box">
#  <div class="exp-header">
#  <div class="exp-logo2" style="width:
#                  15%">
#  <img src="https://github.com/JVJplus/resume/blob/master/images/vvs%20logo.jpg?raw=true"/>
#  </div>
#  <div class="exp-degination2" style="padding: 0">
#  <h2>Intermediate</h2>
#  </div>
#  </div> <!-- Header -->
#  <div class="exp-company2" style="margin-top: -6%">
#  <a href="http://www.valleyviewschooljsr.com/" style="text-decoration: none;" target="_blank">
#  <h3>Valley View School</h3>
#  </a>
#  </div> <!-- Intitution -->
#  <div class="exp-time2">
#  <h4>May 2017 - May 2019</h4>
#  </div>
#  <div class="exp-details2">
#  <p>
#                  Given my ISC exam from CBSE Board with Science Stream and secured 78.6%.
#                  <br/>
#  <br/>
#                  To be  honest It was really difficult! :P
#              </p>
#  </div> <!-- edu-details -->
#  </div> <!-- Timeline-box -->
#  <div class="exp-timeline-box">
#  <div class="exp-header">
#  <div class="exp-logo2 exp-smaller-img2" style="margin-top: 2%;">
#  <img src="https://ninjasfiles.s3.amazonaws.com/asset_0000000000000030_1550710829_ninjasicon.png"/>
#  </div>
#  <div class="exp-degination2">
#  <h2>Online Courses</h2>
#  </div>
#  </div> <!-- Header -->
#  <div class="exp-company2" style="margin-top: -3%">
#  <a href="https://www.codingninjas.in/" style="text-decoration: none" target="_blank">
#  <h3>Coding Ninjas</h3>
#  </a>
#  </div> <!-- Intitution -->
#  <div class="exp-time2">
#  <h4>2017 - 2021 </h4>
#  </div>
#  <div class="exp-details2">
#  <p>
#                  Did Many courses on online sites like udemy, edx etc.
#                  <br/>
#  <br/>
#                  Did Data Structures, Competitive Programming, Full Stack Web Development Courses From Coding Ninjas Website.
#              </p>
#  </div> <!-- edu-details -->
#  </div> <!-- Timeline-box -->
#  <!-- Timeline Divider -->
#  <div class="exp-timeline-divider2">
#  <div class="timeline-traveller">
#  <div>
#  <i class="fas fa-spider"></i>
#  </div>
#  </div>
#  </div> <!-- Timline-Divider -->
#  </div>,
#  <div class="exp-timeline-box">
#  <div class="exp-header">
#  <div class="exp-logo2" style="margin-top: 10px ">
#  <img src="https://github.com/JVJplus/resume/blob/master/images/dav-logo-removebg-preview.png?raw=true"/>
#  </div>
#  <div class="exp-degination2">
#  <h2>Board</h2>
#  </div>
#  </div> <!-- Header -->
#  <div class="exp-company" style="margin-top: -7%">
#  <a href="http://www.davpatelnagar.com/" style="text-decoration: none" target="_blank">
#  <h3>DAV Public School</h3>
#  </a>
#  </div> <!-- Intitution -->
#  <div class="exp-time2">
#  <h4> 2007 - May 2017 </h4>
#  </div>
#  <div class="exp-details2">
#  <p>
#                      Given my board exam from ICSE Board with Science Stream and secured 85.4%. I was also 2nd school topper. Also I got 99% marks in computer science.
#                  </p>
#  </div> <!-- edu-details -->
#  </div>,
#  <div class="exp-header">
#  <div class="exp-logo2" style="margin-top: 10px ">
#  <img src="https://github.com/JVJplus/resume/blob/master/images/dav-logo-removebg-preview.png?raw=true"/>
#  </div>
#  <div class="exp-degination2">
#  <h2>Board</h2>
#  </div>
#  </div>,
#  <div class="exp-logo2" style="margin-top: 10px ">
#  <img src="https://github.com/JVJplus/resume/blob/master/images/dav-logo-removebg-preview.png?raw=true"/>
#  </div>,
#  <div class="exp-degination2">
#  <h2>Board</h2>
#  </div>,
#  <div class="exp-company" style="margin-top: -7%">
#  <a href="http://www.davpatelnagar.com/" style="text-decoration: none" target="_blank">
#  <h3>DAV Public School</h3>
#  </a>
#  </div>,
#  <div class="exp-time2">
#  <h4> 2007 - May 2017 </h4>
#  </div>,
#  <div class="exp-details2">
#  <p>
#                      Given my board exam from ICSE Board with Science Stream and secured 85.4%. I was also 2nd school topper. Also I got 99% marks in computer science.
#                  </p>
#  </div>,
#  <div class="exp-timeline-box">
#  <div class="exp-header">
#  <div class="exp-logo2" style="width:
#                  15%">
#  <img src="https://github.com/JVJplus/resume/blob/master/images/vvs%20logo.jpg?raw=true"/>
#  </div>
#  <div class="exp-degination2" style="padding: 0">
#  <h2>Intermediate</h2>
#  </div>
#  </div> <!-- Header -->
#  <div class="exp-company2" style="margin-top: -6%">
#  <a href="http://www.valleyviewschooljsr.com/" style="text-decoration: none;" target="_blank">
#  <h3>Valley View School</h3>
#  </a>
#  </div> <!-- Intitution -->
#  <div class="exp-time2">
#  <h4>May 2017 - May 2019</h4>
#  </div>
#  <div class="exp-details2">
#  <p>
#                  Given my ISC exam from CBSE Board with Science Stream and secured 78.6%.
#                  <br/>
#  <br/>
#                  To be  honest It was really difficult! :P
#              </p>
#  </div> <!-- edu-details -->
#  </div>,
#  <div class="exp-header">
#  <div class="exp-logo2" style="width:
#                  15%">
#  <img src="https://github.com/JVJplus/resume/blob/master/images/vvs%20logo.jpg?raw=true"/>
#  </div>
#  <div class="exp-degination2" style="padding: 0">
#  <h2>Intermediate</h2>
#  </div>
#  </div>,
#  <div class="exp-logo2" style="width:
#                  15%">
#  <img src="https://github.com/JVJplus/resume/blob/master/images/vvs%20logo.jpg?raw=true"/>
#  </div>,
#  <div class="exp-degination2" style="padding: 0">
#  <h2>Intermediate</h2>
#  </div>,
#  <div class="exp-company2" style="margin-top: -6%">
#  <a href="http://www.valleyviewschooljsr.com/" style="text-decoration: none;" target="_blank">
#  <h3>Valley View School</h3>
#  </a>
#  </div>,
#  <div class="exp-time2">
#  <h4>May 2017 - May 2019</h4>
#  </div>,
#  <div class="exp-details2">
#  <p>
#                  Given my ISC exam from CBSE Board with Science Stream and secured 78.6%.
#                  <br/>
#  <br/>
#                  To be  honest It was really difficult! :P
#              </p>
#  </div>,
#  <div class="exp-timeline-box">
#  <div class="exp-header">
#  <div class="exp-logo2 exp-smaller-img2" style="margin-top: 2%;">
#  <img src="https://ninjasfiles.s3.amazonaws.com/asset_0000000000000030_1550710829_ninjasicon.png"/>
#  </div>
#  <div class="exp-degination2">
#  <h2>Online Courses</h2>
#  </div>
#  </div> <!-- Header -->
#  <div class="exp-company2" style="margin-top: -3%">
#  <a href="https://www.codingninjas.in/" style="text-decoration: none" target="_blank">
#  <h3>Coding Ninjas</h3>
#  </a>
#  </div> <!-- Intitution -->
#  <div class="exp-time2">
#  <h4>2017 - 2021 </h4>
#  </div>
#  <div class="exp-details2">
#  <p>
#                  Did Many courses on online sites like udemy, edx etc.
#                  <br/>
#  <br/>
#                  Did Data Structures, Competitive Programming, Full Stack Web Development Courses From Coding Ninjas Website.
#              </p>
#  </div> <!-- edu-details -->
#  </div>,
#  <div class="exp-header">
#  <div class="exp-logo2 exp-smaller-img2" style="margin-top: 2%;">
#  <img src="https://ninjasfiles.s3.amazonaws.com/asset_0000000000000030_1550710829_ninjasicon.png"/>
#  </div>
#  <div class="exp-degination2">
#  <h2>Online Courses</h2>
#  </div>
#  </div>,
#  <div class="exp-logo2 exp-smaller-img2" style="margin-top: 2%;">
#  <img src="https://ninjasfiles.s3.amazonaws.com/asset_0000000000000030_1550710829_ninjasicon.png"/>
#  </div>,
#  <div class="exp-degination2">
#  <h2>Online Courses</h2>
#  </div>,
#  <div class="exp-company2" style="margin-top: -3%">
#  <a href="https://www.codingninjas.in/" style="text-decoration: none" target="_blank">
#  <h3>Coding Ninjas</h3>
#  </a>
#  </div>,
#  <div class="exp-time2">
#  <h4>2017 - 2021 </h4>
#  </div>,
#  <div class="exp-details2">
#  <p>
#                  Did Many courses on online sites like udemy, edx etc.
#                  <br/>
#  <br/>
#                  Did Data Structures, Competitive Programming, Full Stack Web Development Courses From Coding Ninjas Website.
#              </p>
#  </div>,
#  <div class="exp-timeline-divider2">
#  <div class="timeline-traveller">
#  <div>
#  <i class="fas fa-spider"></i>
#  </div>
#  </div>
#  </div>,
#  <div class="timeline-traveller">
#  <div>
#  <i class="fas fa-spider"></i>
#  </div>
#  </div>,
#  <div>
#  <i class="fas fa-spider"></i>
#  </div>,
#  <div class="section-header" id="portfolio-title">
#  <i class="far fa-image"></i>
#  <span>Portfolio</span>
#  </div>,
#  <div class="portfolio-container">
#  <div class="portfolio-image-container" id="port1">
#  <!-- <img class="portfolio-image" src="https://i.ibb.co/JrWZj3h/1.jpg"> -->
#  <img class="portfolio-image" src="https://raw.githubusercontent.com/JVJplus/Resume-Webpage/master/images/Portfolio/img%201.jpg"/>
#  <div class="portfolio-details">
#  <p>
#                      Green Wave Effect with Horizontal Overlays
#                  </p>
#  </div>
#  </div>
#  <div class="portfolio-image-container" id="port2">
#  <img class="portfolio-image" src="https://raw.githubusercontent.com/JVJplus/Resume-Webpage/master/images/Portfolio/img%202.jpg"/>
#  <div class="portfolio-details">
#  <p>
#                      Computer RAM Representing Passion For Computer.
#                  </p>
#  </div>
#  </div>
#  <div class="portfolio-image-container" id="port3">
#  <img class="portfolio-image" src="https://raw.githubusercontent.com/JVJplus/Resume-Webpage/master/images/Portfolio/img%203.jpg"/>
#  <div class="portfolio-details">
#  <p>
#                      Earth Axis Representing The Love!
#                  </p>
#  </div>
#  </div>
#  <div class="portfolio-image-container" id="port4">
#  <img class="portfolio-image" src="https://raw.githubusercontent.com/JVJplus/Resume-Webpage/master/images/Portfolio/img%204.jpg"/>
#  <div class="portfolio-details">
#  <p>
#                      Old Steel Effect looks Great!
#                  </p>
#  </div>
#  </div>
#  <div class="portfolio-image-container" id="port5">
#  <img class="portfolio-image" src="https://raw.githubusercontent.com/JVJplus/Resume-Webpage/master/images/Portfolio/img%205.jpg"/>
#  <div class="portfolio-details">
#  <p>
#                      One of my favourite Blood effects!
#                  </p>
#  </div>
#  </div>
#  <div class="portfolio-image-container" id="port6">
#  <img class="portfolio-image" src="https://raw.githubusercontent.com/JVJplus/Resume-Webpage/master/images/Portfolio/img%206.jpg"/>
#  <div class="portfolio-details">
#  <p>
#                      Hmm Random Text overlay over image!
#                  </p>
#  </div>
#  </div>
#  </div>,
#  <div class="portfolio-image-container" id="port1">
#  <!-- <img class="portfolio-image" src="https://i.ibb.co/JrWZj3h/1.jpg"> -->
#  <img class="portfolio-image" src="https://raw.githubusercontent.com/JVJplus/Resume-Webpage/master/images/Portfolio/img%201.jpg"/>
#  <div class="portfolio-details">
#  <p>
#                      Green Wave Effect with Horizontal Overlays
#                  </p>
#  </div>
#  </div>,
#  <div class="portfolio-details">
#  <p>
#                      Green Wave Effect with Horizontal Overlays
#                  </p>
#  </div>,
#  <div class="portfolio-image-container" id="port2">
#  <img class="portfolio-image" src="https://raw.githubusercontent.com/JVJplus/Resume-Webpage/master/images/Portfolio/img%202.jpg"/>
#  <div class="portfolio-details">
#  <p>
#                      Computer RAM Representing Passion For Computer.
#                  </p>
#  </div>
#  </div>,
#  <div class="portfolio-details">
#  <p>
#                      Computer RAM Representing Passion For Computer.
#                  </p>
#  </div>,
#  <div class="portfolio-image-container" id="port3">
#  <img class="portfolio-image" src="https://raw.githubusercontent.com/JVJplus/Resume-Webpage/master/images/Portfolio/img%203.jpg"/>
#  <div class="portfolio-details">
#  <p>
#                      Earth Axis Representing The Love!
#                  </p>
#  </div>
#  </div>,
#  <div class="portfolio-details">
#  <p>
#                      Earth Axis Representing The Love!
#                  </p>
#  </div>,
#  <div class="portfolio-image-container" id="port4">
#  <img class="portfolio-image" src="https://raw.githubusercontent.com/JVJplus/Resume-Webpage/master/images/Portfolio/img%204.jpg"/>
#  <div class="portfolio-details">
#  <p>
#                      Old Steel Effect looks Great!
#                  </p>
#  </div>
#  </div>,
#  <div class="portfolio-details">
#  <p>
#                      Old Steel Effect looks Great!
#                  </p>
#  </div>,
#  <div class="portfolio-image-container" id="port5">
#  <img class="portfolio-image" src="https://raw.githubusercontent.com/JVJplus/Resume-Webpage/master/images/Portfolio/img%205.jpg"/>
#  <div class="portfolio-details">
#  <p>
#                      One of my favourite Blood effects!
#                  </p>
#  </div>
#  </div>,
#  <div class="portfolio-details">
#  <p>
#                      One of my favourite Blood effects!
#                  </p>
#  </div>,
#  <div class="portfolio-image-container" id="port6">
#  <img class="portfolio-image" src="https://raw.githubusercontent.com/JVJplus/Resume-Webpage/master/images/Portfolio/img%206.jpg"/>
#  <div class="portfolio-details">
#  <p>
#                      Hmm Random Text overlay over image!
#                  </p>
#  </div>
#  </div>,
#  <div class="portfolio-details">
#  <p>
#                      Hmm Random Text overlay over image!
#                  </p>
#  </div>,
#  <div class="section-header contact-section-header">
#  <i class="far fa-address-card"></i>
#  <span>Contact</span>
#  </div>,
#  <div id="contact-container">
#  <div class="contact-sections-container" id="feedback">
#  <form action="mailto:jvjplus@gmail.com" class="feedback-form" method="GET">
#  <input class="contact-form-input-box" name="Name" placeholder="Your Name" type="text"/>
#  <input class="contact-form-input-box" name="Email" placeholder="Your Email" type="email"/>
#  <!-- <input type="text" name="Message" placeholder="Message" class="contact-form-input-box" required="" id="message-input"> -->
#  <textarea class="contact-form-input-box" id="message-input" placeholder="Message"></textarea>
#  <!--   <input type="submit" name="Send Message" value="SEND MESSAGE" id="send-message"> -->
#  <button id="send-message" name="Send Message" type="submit" value="">SEND MESSAGE</button>
#  </form>
#  </div> <!-- 1st column -->
#  <div class="contact-sections-container" id="about-us">
#  <span>
#  <h4 class="about-us-title">
#                  Get In Touch
#              </h4>
#  </span>
#  <span>
#  <p>
#                  For any kind of help, doubts, questions etc related to computer, programming, designing, music.
#                  <br/>
#  <br/>
#                  I am be found offline ofcourse, apart from it I am available on major social sites.
#              </p>
#  </span>
#  <span>
#  <h4 class="about-us-title address-title">
#                  My Address
#              </h4>
#  </span>
#  <div class="contact-address">
#  <div>
#  <a href="https://goo.gl/maps/eSfpCDVmc972PaBr8" target="_blank">
#  <i class="fas fa-map-marker-alt" style="color: white;"></i>
#  <p> Telco, Jamshedpur, Jharkhand</p>
#  </a>
#  </div>
#  <div>
#  <a href="https://wa.me/919835582472?text=Hi Jay!!" target="_blank">
#  <i class="fas fa-mobile-alt" style="color: white;"></i>
#  <p> 9835582472</p>
#  </a>
#  </div>
#  <div>
#  <a href="mailto:jvjplus@gmail.com?Subject=Hello" target="_top">
#  <i class="far fa-envelope" style="color: white;"></i>
#  <p> jvjplus@gmail.com</p>
#  </a>
#  </div>
#  </div> <!-- Contact us column -->
#  </div> <!-- About Us Column -->
#  </div>,
#  <div class="contact-sections-container" id="feedback">
#  <form action="mailto:jvjplus@gmail.com" class="feedback-form" method="GET">
#  <input class="contact-form-input-box" name="Name" placeholder="Your Name" type="text"/>
#  <input class="contact-form-input-box" name="Email" placeholder="Your Email" type="email"/>
#  <!-- <input type="text" name="Message" placeholder="Message" class="contact-form-input-box" required="" id="message-input"> -->
#  <textarea class="contact-form-input-box" id="message-input" placeholder="Message"></textarea>
#  <!--   <input type="submit" name="Send Message" value="SEND MESSAGE" id="send-message"> -->
#  <button id="send-message" name="Send Message" type="submit" value="">SEND MESSAGE</button>
#  </form>
#  </div>,
#  <div class="contact-sections-container" id="about-us">
#  <span>
#  <h4 class="about-us-title">
#                  Get In Touch
#              </h4>
#  </span>
#  <span>
#  <p>
#                  For any kind of help, doubts, questions etc related to computer, programming, designing, music.
#                  <br/>
#  <br/>
#                  I am be found offline ofcourse, apart from it I am available on major social sites.
#              </p>
#  </span>
#  <span>
#  <h4 class="about-us-title address-title">
#                  My Address
#              </h4>
#  </span>
#  <div class="contact-address">
#  <div>
#  <a href="https://goo.gl/maps/eSfpCDVmc972PaBr8" target="_blank">
#  <i class="fas fa-map-marker-alt" style="color: white;"></i>
#  <p> Telco, Jamshedpur, Jharkhand</p>
#  </a>
#  </div>
#  <div>
#  <a href="https://wa.me/919835582472?text=Hi Jay!!" target="_blank">
#  <i class="fas fa-mobile-alt" style="color: white;"></i>
#  <p> 9835582472</p>
#  </a>
#  </div>
#  <div>
#  <a href="mailto:jvjplus@gmail.com?Subject=Hello" target="_top">
#  <i class="far fa-envelope" style="color: white;"></i>
#  <p> jvjplus@gmail.com</p>
#  </a>
#  </div>
#  </div> <!-- Contact us column -->
#  </div>,
#  <div class="contact-address">
#  <div>
#  <a href="https://goo.gl/maps/eSfpCDVmc972PaBr8" target="_blank">
#  <i class="fas fa-map-marker-alt" style="color: white;"></i>
#  <p> Telco, Jamshedpur, Jharkhand</p>
#  </a>
#  </div>
#  <div>
#  <a href="https://wa.me/919835582472?text=Hi Jay!!" target="_blank">
#  <i class="fas fa-mobile-alt" style="color: white;"></i>
#  <p> 9835582472</p>
#  </a>
#  </div>
#  <div>
#  <a href="mailto:jvjplus@gmail.com?Subject=Hello" target="_top">
#  <i class="far fa-envelope" style="color: white;"></i>
#  <p> jvjplus@gmail.com</p>
#  </a>
#  </div>
#  </div>,
#  <div>
#  <a href="https://goo.gl/maps/eSfpCDVmc972PaBr8" target="_blank">
#  <i class="fas fa-map-marker-alt" style="color: white;"></i>
#  <p> Telco, Jamshedpur, Jharkhand</p>
#  </a>
#  </div>,
#  <div>
#  <a href="https://wa.me/919835582472?text=Hi Jay!!" target="_blank">
#  <i class="fas fa-mobile-alt" style="color: white;"></i>
#  <p> 9835582472</p>
#  </a>
#  </div>,
#  <div>
#  <a href="mailto:jvjplus@gmail.com?Subject=Hello" target="_top">
#  <i class="far fa-envelope" style="color: white;"></i>
#  <p> jvjplus@gmail.com</p>
#  </a>
#  </div>,
#  <div id="social-icons-bottom">
#  <ul class="horizontal-list" id="social">
#  <li class="horizontal-list-item">
#  <a href="https://wa.me/919835582472?text=Hi Jay!!" target="_blank">
#  <i class="fab fa-whatsapp"></i>
#  </a>
#  </li>
#  <li class="horizontal-list-item">
#  <a href="https://www.facebook.com/JVJplus" target="_blank">
#  <i class="fab fa-facebook-f"></i>
#  </a>
#  </li>
#  <li class="horizontal-list-item">
#  <a href="https://www.instagram.com/JVJplus" target="_blank">
#  <i class="fab fa-instagram"></i>
#  </a>
#  </li>
#  <li class="horizontal-list-item">
#  <a href="https://github.com/JVJplus" target="_blank">
#  <i class="fab fa-github"></i>
#  </a>
#  </li>
#  <li class="horizontal-list-item">
#  <a href="https://profile.codingninjas.in/b38c7b90-7719-418b-8211-a9468ae7001b" target="_blank">
#  <i class="fas fa-user-ninja"></i>
#  </a>
#  </li>
#  </ul>
#  </div>]

# %%
soup.find_all('li',{'class':'horizontal-list-item'})
# Out:
# [<li class="horizontal-list-item"> <a href="#body-header">Home</a></li>,
#  <li class="horizontal-list-item"> <a href="#about">About</a></li>,
#  <li class="horizontal-list-item"> <a href="#skills">Skills</a></li>,
#  <li class="horizontal-list-item"> <a href="#experience">Experience</a></li>,
#  <li class="horizontal-list-item"> <a href="#education">Education</a></li>,
#  <li class="horizontal-list-item"> <a href="#portfolio">Portfolio</a></li>,
#  <li class="horizontal-list-item"> <a href="#contact">Contact</a></li>,
#  <li class="horizontal-list-item">
#  <a href="https://wa.me/919835582472?text=Hi Jay!!" target="_blank">
#  <i class="fab fa-whatsapp"></i>
#  </a>
#  </li>,
#  <li class="horizontal-list-item">
#  <a href="https://www.facebook.com/JVJplus" target="_blank">
#  <i class="fab fa-facebook-f"></i>
#  </a>
#  </li>,
#  <li class="horizontal-list-item">
#  <a href="https://www.instagram.com/JVJplus" target="_blank">
#  <i class="fab fa-instagram"></i>
#  </a>
#  </li>,
#  <li class="horizontal-list-item">
#  <a href="https://github.com/JVJplus" target="_blank">
#  <i class="fab fa-github"></i>
#  </a>
#  </li>,
#  <li class="horizontal-list-item">
#  <a href="https://profile.codingninjas.in/b38c7b90-7719-418b-8211-a9468ae7001b" target="_blank">
#  <i class="fas fa-user-ninja"></i>
#  </a>
#  </li>,
#  <li class="horizontal-list-item">
#  <a href="https://wa.me/919835582472?text=Hi Jay!!" target="_blank">
#  <i class="fab fa-whatsapp"></i>
#  </a>
#  </li>,
#  <li class="horizontal-list-item">
#  <a href="https://www.facebook.com/JVJplus" target="_blank">
#  <i class="fab fa-facebook-f"></i>
#  </a>
#  </li>,
#  <li class="horizontal-list-item">
#  <a href="https://www.instagram.com/JVJplus" target="_blank">
#  <i class="fab fa-instagram"></i>
#  </a>
#  </li>,
#  <li class="horizontal-list-item">
#  <a href="https://github.com/JVJplus" target="_blank">
#  <i class="fab fa-github"></i>
#  </a>
#  </li>,
#  <li class="horizontal-list-item">
#  <a href="https://profile.codingninjas.in/b38c7b90-7719-418b-8211-a9468ae7001b" target="_blank">
#  <i class="fas fa-user-ninja"></i>
#  </a>
#  </li>]

# %%
a=["afdaadsv",'xxxsfdadsf']
c="1".join(a)
c
# Out:
# 'afdaadsv1xxxsfdadsf'
